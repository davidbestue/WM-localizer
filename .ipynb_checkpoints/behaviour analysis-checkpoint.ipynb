# %%
from linares_plot import *
import os

# %%
file_WMloc ='C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\1.txt' 
df = pd.read_csv(file_WMloc, sep=" ") 
df =df[['first_second', 'radius', 'angle_t1', 'angle_t2', 'angle_p1', 'angle_p2', 'correct_direction', 'Response', 'C_I_M', 'start_trial', 
   'presentation_checkboard_time', 'presentation_target_time', 'start_delay',  'end_delay', 'presentation_probe_time', 'response_time' ]]

# %%
root='C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo'
filenames = os.listdir(root)   
files_wmloc=[]

for file in filenames: 
    path_sess = os.path.join( root, file)
    #print(path_sess)
    dirs_sess = os.listdir(path_sess)
    for i in range(len(dirs_sess)):
        if dirs_sess[i].find("WM_mapping") != -1:
            path_wm_file =  os.path.join( path_sess, dirs_sess[i] )
            files_wmloc.append( path_wm_file)


            
# remove .py
files_wmloc = list(np.array(files_wmloc)[ np.array([files_wmloc[i].find(".py") for i in range(len(files_wmloc))])==-1 ] )
files_wmloc
# Out:
# ['C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20171205\\David_51217_4_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20171207\\r001_71217_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20171207\\r001_71217_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180227\\r001_270218_3_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180312\\r001_120318_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180829\\d001_29082018_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180911\\d001_110918_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180912\\d001_120918_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180912\\r001_120918_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180914\\n001_140918_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180926\\b001_260918_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180926\\b001_260918_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180927\\b001_270918_3_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180927\\b001_270918_4_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180927\\s001_270918_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180927\\s001_270918_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20180927\\s001_270918_3_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\d001_011018_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\d001_011018_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\d001_011018_3_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\d001_011018_4_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\n001_11018_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\n001_11018_3_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181001\\n001_11018_4_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181002\\l001_021018_1_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181002\\l001_021018_2_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181002\\l001_021018_3_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181002\\l001_021018_4_WM_mapping',
#  'C:\\Users\\David\\Documents\\GitHub\\WM-localizer\\tempo\\20181004\\s001_041018_4_WM_mapping']

# %%
for i in range(len(dirs_sess)):
    if dirs_sess[i].find("WM_mapping") != -1:
        print(dirs_sess[i])
# Out:
# d001_29082018_WM_mapping

# %%
dirs_sess[-2]
# Out:
# 'd001_29082018_WM_mapping'

# %%
df.head(10)
## C_I_M stands for correct (0), incorrect (1), miss (999) or the other way arround. 
## We accept that the one with more is correct. 
## If the same, exclude the subject
# Out:
#    first_second  radius  angle_t1  angle_t2  angle_p1  angle_p2  \
# 0        41.292  41.292    41.292    41.292    41.292    41.292
# 1         1.000  14.000   160.000   135.000   151.000   126.000
# 2         2.000  14.000   160.000   135.000   151.000   126.000
# 3         1.000  14.000    12.000    69.000    10.000    76.000
# 4         2.000  14.000    12.000    69.000    10.000    76.000
# 5         1.000  14.000   218.000   229.000   217.000   226.000
# 6         2.000  14.000   218.000   229.000   217.000   226.000
# 7         1.000  14.000   240.000   191.000   239.000   190.000
# 8         2.000  14.000   240.000   191.000   239.000   190.000
# 9         1.000  14.000   344.000   327.000   340.000   331.000
#
#    correct_direction  Response    C_I_M  start_trial  \
# 0             41.292    41.292   41.292       41.292
# 1              1.000     0.000  999.000       43.757
# 2              1.000     0.000  999.000       43.757
# 3             -1.000     1.000    1.000       59.512
# 4              1.000    -1.000    1.000       59.512
# 5              1.000     1.000    0.000       75.143
# 6              1.000    -1.000    1.000       75.143
# 7              1.000    -1.000    1.000       90.733
# 8              1.000     1.000    0.000       90.733
# 9             -1.000    -1.000    0.000      106.597
#
#    presentation_checkboard_time  presentation_target_time  start_delay  \
# 0                        41.292                    41.292       41.292
# 1                        43.757                    44.215       44.546
# 2                        43.757                    50.519       50.851
# 3                        59.512                    59.840       60.308
# 4                        59.512                    65.814       66.145
# 5                        75.143                    75.604       75.936
# 6                        75.143                    80.992       81.473
# 7                        90.733                    90.982       91.464
# 8                        90.733                    96.803       97.134
# 9                       106.597                   107.061      107.528
#
#    end_delay  presentation_probe_time  response_time
# 0     41.292                   41.292         41.292
# 1     47.718                   47.718          0.000
# 2     54.022                   54.022          0.000
# 3     63.343                   63.343         64.260
# 4     69.317                   69.317         70.048
# 5     79.107                   79.107         80.057
# 6     84.494                   84.494         85.178
# 7     94.485                   94.485         95.635
# 8    100.306                  100.306        101.240
# 9    110.563                  110.563        113.132

# %%
if sum(df['C_I_M']==1) > sum(df['C_I_M']==0):
    df['CIM']=df['C_I_M'].replace([0,1,999], ['wrong', 'correct', 'miss'])
elif sum(df['C_I_M']==0) > sum(df['C_I_M']==1):
    df['CIM']=df['C_I_M'].replace([0,1,999], ['correct', 'wrong', 'miss'])
else:
    print('Exclude')

# %%
#print(sum(df['CIM']=='miss'))
#print(sum(df['CIM']=='wrong'))
#print(sum(df['CIM']=='correct'))

plt.bar([0,1,2], [sum(df['CIM']=='correct'), sum(df['CIM']=='wrong'), sum(df['CIM']=='miss')], 
       color = ['g', 'r', 'k'])
plt.xticks([0,1,2], ['correct', 'wrong', 'miss'])
plt.gca().spines['right'].set_visible(False)  ## aesthetics                                                                              # remove right spines
plt.gca().spines['top'].set_visible(False)                                                                                  # remove top spines
plt.gca().get_xaxis().tick_bottom()                                                                                         
plt.gca().get_yaxis().tick_left()
plt.gca().tick_params(direction='in') #direction
